# %% [markdown]
# <a href="https://colab.research.google.com/github/posanikrishnateja/DAA-practicals/blob/main/DAA_Practical02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1


# User input
arr = list(map(int, input("Enter elements: ").split()))
target = int(input("Enter element to search: "))

# Measure execution time
start_time = time.perf_counter()

result = linear_search(arr, target)

end_time = time.perf_counter()

# Output
if result != -1:
    print("Element found at index:", result)
else:
    print("Element not found")

print("Execution time:", end_time - start_time, "seconds")
# Out:
# Enter elements: 3 9 5 2 8
# Enter element to search: 1
# Element not found
# Execution time: 9.043000000019674e-05 seconds

# %%
import time

def binary_search(arr, target):
    low = 0
    high = len(arr) - 1

    while low <= high:
        mid = (low + high) // 2

        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1

    return -1


# User input
arr = list(map(int, input("Enter sorted elements: ").split()))
target = int(input("Enter element to search: "))

# Measure execution time
start_time = time.perf_counter()

result = binary_search(arr, target)

end_time = time.perf_counter()

# Output
if result != -1:
    print("Element found at index:", result)
else:
    print("Element not found")

print("Execution time:", end_time - start_time, "seconds")
# Out:
# Enter sorted elements: 2 5 7 8 9
# Enter element to search: 5
# Element found at index: 1
# Execution time: 8.275999994111771e-05 seconds
