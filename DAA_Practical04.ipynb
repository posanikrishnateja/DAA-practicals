# %% [markdown]
# <a href="https://colab.research.google.com/github/posanikrishnateja/DAA-practicals/blob/main/DAA_Practical04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

def fibonacci_iterative(n):
    a = 0
    b = 1

    for i in range(n):
        print(a, end=" ")
        a, b = b, a + b


# User input
n = int(input("Enter number of terms: "))

# Start time
start_time = time.perf_counter()

fibonacci_iterative(n)

# End time
end_time = time.perf_counter()

print("\nExecution time:", end_time - start_time, "seconds")
# Out:
# Enter number of terms: 7
# 0 1 1 2 3 5 8
# Execution time: 0.00019376000000193017 seconds

# %%
import time

def fibonacci_recursive(n):
    if n <= 1:
        return n

    return fibonacci_recursive(n - 1) + fibonacci_recursive(n - 2)


# User input
n = int(input("Enter number of terms: "))

# Start time
start_time = time.perf_counter()

for i in range(n):
    print(fibonacci_recursive(i), end=" ")

# End time
end_time = time.perf_counter()

print("\nExecution time:", end_time - start_time, "seconds")
# Out:
# Enter number of terms: 4
# 0 1 1 2
# Execution time: 0.00021096999989822507 seconds
